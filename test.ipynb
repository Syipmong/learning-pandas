# %%
import pandas as pd

# %%
#creating a dataframe
pd.DataFrame({"Yes": [50, 100], "No":[30,80]})
# Out:
#    Yes  No
# 0   50  30
# 1  100  80

# %%
pd.DataFrame({"Name":["Joshua", "David","John"], "Age":[30,50,20]})
# Out:
#      Name  Age
# 0  Joshua   30
# 1   David   50
# 2    John   20

# %%
#assigning of indexes instead of using the default

pd.DataFrame({"Name":["Joshua", "David","John"], "Age":[30,50,20]}, index=[1,2,3])
# Out:
#      Name  Age
# 1  Joshua   30
# 2   David   50
# 3    John   20

# %%
#Series

pd.Series([2,5,3,7,5])
# Out:
# 0    2
# 1    5
# 2    3
# 3    7
# 4    5
# dtype: int64

# %%
pd.Series([2,5,3,7,5], index=["cows","cattles","dogs","cats","rabbit"] , name="Pet names")
# Out:
# cows       2
# cattles    5
# dogs       3
# cats       7
# rabbit     5
# Name: Pet names, dtype: int64

# %%
pd.DataFrame({"Apples":[30], "Bananas":[20]})
# Out:
#    Apples  Bananas
# 0      30       20

# %%
pd.Series(["4 cups", "1 cup", "2 large", "1 can"], index=["Flour", "Milk", "Eggs", "Spam"], name="Dinner")
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
testme=pd.DataFrame({"Name":["Joshua", "David","John"], "Age":[30,50,20]}, index=[1,2,3])
testme.to_csv("newfile.csv")

# %%
file_pth = "newfile.csv"
pd.read_csv(file_pth)
# Out:
#    Unnamed: 0    Name  Age
# 0           1  Joshua   30
# 1           2   David   50
# 2           3    John   20

# %%
file_path = "winemag-data_first150k.csv"
reviews = pd.read_csv(file_path)
reviews.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
desc = reviews.description.iloc[0]
desc
# Out:
# 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.'

# %%
type(desc)
# Out:
# str

# %%
sample_data = reviews.loc[[1,2,3,5,8]]

sample_data
# Out:
#    Unnamed: 0 country                                        description  \
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 5           5   Spain  Deep, dense and pure from the opening bell, th...
# 8           8      US  This re-named vineyard was formerly bottled as...
#
#                             designation  points  price        province  \
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 5                             Numanthia      95   73.0  Northern Spain
# 8                                Silice      95   65.0          Oregon
#
#              region_1           region_2          variety  \
# 1                Toro                NaN    Tinta de Toro
# 2      Knights Valley             Sonoma  Sauvignon Blanc
# 3   Willamette Valley  Willamette Valley       Pinot Noir
# 5                Toro                NaN    Tinta de Toro
# 8  Chehalem Mountains  Willamette Valley       Pinot Noir
#
#                     winery
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 5                Numanthia
# 8                Bergström

# %%
df = reviews.loc[[1,2,3,5,8], ['country', 'province', 'region_1', 'region_2']]
df
# Out:
#   country        province            region_1           region_2
# 1   Spain  Northern Spain                Toro                NaN
# 2      US      California      Knights Valley             Sonoma
# 3      US          Oregon   Willamette Valley  Willamette Valley
# 5   Spain  Northern Spain                Toro                NaN
# 8      US          Oregon  Chehalem Mountains  Willamette Valley

# %%
oceania_wines = reviews[(reviews.points >= 95) & (reviews.country == 'Australia') | (reviews.country == 'New Zealand')]

oceania_wines
# Out:
#         Unnamed: 0      country  \
# 25              25  New Zealand
# 305            305  New Zealand
# 1171          1171  New Zealand
# 1184          1184  New Zealand
# 1185          1185  New Zealand
# ...            ...          ...
# 150378      150378  New Zealand
# 150382      150382  New Zealand
# 150389      150389  New Zealand
# 150562      150562    Australia
# 150563      150563    Australia
#
#                                               description  \
# 25      Yields were down in 2015, but intensity is up,...
# 305     Yields were down in 2015, but intensity is up,...
# 1171    Usually the bigger, more opulent of the Kumeu ...
# 1184    Envoy is Spy Valley's top range of bottlings. ...
# 1185    This wine shows a fine balance between sweetne...
# ...                                                   ...
# 150378  Impressive purple color, but less intense on t...
# 150382  Features classic Marlborough aromas, marrying ...
# 150389  Aromas of peach and pineapple give way to trop...
# 150562  As unevolved as they are, the dense and multil...
# 150563  Seamless luxury from stem to stern, this ‘baby...
#
#                    designation  points  price         province  \
# 25             Maté's Vineyard      94   57.0            Kumeu
# 305            Maté's Vineyard      94   57.0            Kumeu
# 1171                Coddington      93   46.0            Kumeu
# 1184    Envoy Johnson Vineyard      93   33.0      Marlborough
# 1185               Bannockburn      93   40.0    Central Otago
# ...                        ...     ...    ...              ...
# 150378                     NaN      84    NaN    Martinborough
# 150382                     NaN      84   16.0      Marlborough
# 150389                     NaN      84   13.0      Marlborough
# 150562                  Grange      96  185.0  South Australia
# 150563                     RWT      95   70.0  South Australia
#
#                region_1 region_2          variety       winery
# 25                  NaN      NaN       Chardonnay  Kumeu River
# 305                 NaN      NaN       Chardonnay  Kumeu River
# 1171                NaN      NaN       Chardonnay  Kumeu River
# 1184                NaN      NaN  Sauvignon Blanc   Spy Valley
# 1185                NaN      NaN         Riesling  Felton Road
# ...                 ...      ...              ...          ...
# 150378              NaN      NaN            Syrah       Kusuda
# 150382              NaN      NaN  Sauvignon Blanc  Saint Clair
# 150389              NaN      NaN  Sauvignon Blanc       Babich
# 150562  South Australia      NaN           Shiraz     Penfolds
# 150563   Barossa Valley      NaN           Shiraz     Penfolds
#
# [3402 rows x 11 columns]

# %%
reviews.points.describe()
# Out:
# count    150930.000000
# mean         87.888418
# std           3.222392
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: points, dtype: float64

# %%
reviews.points.mean()
# Out:
# 87.8884184721394

# %%
reviews.points.median()
# Out:
# 88.0

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  score  price  \
# 0                          Martha's Vineyard     96  235.0
# 1       Carodorum Selección Especial Reserva     96  110.0
# 2              Special Selected Late Harvest     96   90.0
# 3                                    Reserve     96   65.0
# 4                                 La Brûlade     95   66.0
# ...                                      ...    ...    ...
# 150925                                   NaN     91   20.0
# 150926                        Cuvée Prestige     91   27.0
# 150927                         Terre di Dora     91   20.0
# 150928                       Grand Brut Rosé     90   52.0
# 150929                                   NaN     90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 11 columns]
